# %% [markdown]
# # Human Resources Data Analysis and Attrition Prediction
#
# _Exploratory Analysis of HR Dataset_
#
# ---
#
# HR analysis helps us to interpret organizational data. It identifies people-related trends in the data, and enables the HR department to take appropriate action to keep the organization running smoothly and profitably. Attrition in a company is one of the complex challenges faced by human resources managers and HR staff.
# Interestingly, machine learning models can be deployed to predict potential cases of attrition, helping HR staff to take the necessary steps to retain the employee.
#
# Before any statistical processing, we need to ensure the quality of our data by (possibly) **cleaning** it - deleting redundant data, formatting strings, deleting NaNs, possibly performing data transformations - and **visualizing** it.

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns 

# %matplotlib inline

# %% [markdown]
# ## Data Loading
#
# _Note:_ In Python, [colormap](https://matplotlib.org/stable/users/explain/colors/colormaps.html) allows easier dataframe visualization.

# %%
data = pd.read_csv('HR-Employee-Attrition.csv')

display( data.head().style.background_gradient(cmap='BuPu') )
# Out:
# <style type="text/css">
# #T_9759d_row0_col0 {
#   background-color: #8c68af;
#   color: #f1f1f1;
# }
# #T_9759d_row0_col3 {
#   background-color: #88449e;
#   color: #f1f1f1;
# }
# #T_9759d_row0_col5, #T_9759d_row0_col8, #T_9759d_row0_col9, #T_9759d_row0_col23, #T_9759d_row0_col24, #T_9759d_row0_col25, #T_9759d_row0_col26, #T_9759d_row0_col27, #T_9759d_row0_col29, #T_9759d_row0_col30, #T_9759d_row0_col33, #T_9759d_row1_col3, #T_9759d_row1_col6, #T_9759d_row1_col8, #T_9759d_row1_col13, #T_9759d_row1_col16, #T_9759d_row1_col20, #T_9759d_row1_col26, #T_9759d_row2_col8, #T_9759d_row2_col13, #T_9759d_row2_col14, #T_9759d_row2_col18, #T_9759d_row2_col19, #T_9759d_row2_col24, #T_9759d_row2_col26, #T_9759d_row2_col27, #T_9759d_row2_col31, #T_9759d_row2_col32, #T_9759d_row2_col33, #T_9759d_row2_col34, #T_9759d_row3_col8, #T_9759d_row3_col14, #T_9759d_row3_col20, #T_9759d_row3_col23, #T_9759d_row3_col24, #T_9759d_row3_col26, #T_9759d_row3_col27, #T_9759d_row3_col34, #T_9759d_row4_col0, #T_9759d_row4_col6, #T_9759d_row4_col8, #T_9759d_row4_col10, #T_9759d_row4_col12, #T_9759d_row4_col14, #T_9759d_row4_col16, #T_9759d_row4_col24, #T_9759d_row4_col26, #T_9759d_row4_col28 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_9759d_row0_col6, #T_9759d_row0_col10, #T_9759d_row1_col33, #T_9759d_row2_col6, #T_9759d_row2_col23, #T_9759d_row2_col25 {
#   background-color: #a9c4de;
#   color: #000000;
# }
# #T_9759d_row0_col12, #T_9759d_row0_col13, #T_9759d_row0_col14, #T_9759d_row0_col16, #T_9759d_row0_col18, #T_9759d_row1_col0, #T_9759d_row1_col5, #T_9759d_row1_col14, #T_9759d_row1_col19, #T_9759d_row1_col23, #T_9759d_row1_col24, #T_9759d_row1_col25, #T_9759d_row1_col27, #T_9759d_row1_col28, #T_9759d_row1_col29, #T_9759d_row1_col30, #T_9759d_row1_col31, #T_9759d_row1_col32, #T_9759d_row1_col34, #T_9759d_row2_col10, #T_9759d_row2_col29, #T_9759d_row2_col30, #T_9759d_row3_col3, #T_9759d_row3_col6, #T_9759d_row3_col10, #T_9759d_row3_col13, #T_9759d_row3_col29, #T_9759d_row3_col30, #T_9759d_row3_col32, #T_9759d_row3_col33, #T_9759d_row4_col9, #T_9759d_row4_col13, #T_9759d_row4_col20, #T_9759d_row4_col25, #T_9759d_row4_col27, #T_9759d_row4_col29, #T_9759d_row4_col30 {
#   background-color: #4d004b;
#   color: #f1f1f1;
# }
# #T_9759d_row0_col19 {
#   background-color: #873d9a;
#   color: #f1f1f1;
# }
# #T_9759d_row0_col20 {
#   background-color: #800f7b;
#   color: #f1f1f1;
# }
# #T_9759d_row0_col28, #T_9759d_row2_col9, #T_9759d_row2_col16, #T_9759d_row3_col16, #T_9759d_row3_col28 {
#   background-color: #8c95c6;
#   color: #f1f1f1;
# }
# #T_9759d_row0_col31 {
#   background-color: #8c74b5;
#   color: #f1f1f1;
# }
# #T_9759d_row0_col32 {
#   background-color: #8c7dba;
#   color: #f1f1f1;
# }
# #T_9759d_row0_col34 {
#   background-color: #894da3;
#   color: #f1f1f1;
# }
# #T_9759d_row1_col9 {
#   background-color: #d6e4f0;
#   color: #000000;
# }
# #T_9759d_row1_col10, #T_9759d_row3_col9, #T_9759d_row3_col25, #T_9759d_row4_col33 {
#   background-color: #8b5daa;
#   color: #f1f1f1;
# }
# #T_9759d_row1_col12 {
#   background-color: #9cb8d8;
#   color: #000000;
# }
# #T_9759d_row1_col18 {
#   background-color: #863595;
#   color: #f1f1f1;
# }
# #T_9759d_row2_col0 {
#   background-color: #92a4cd;
#   color: #f1f1f1;
# }
# #T_9759d_row2_col3 {
#   background-color: #540251;
#   color: #f1f1f1;
# }
# #T_9759d_row2_col5, #T_9759d_row4_col5 {
#   background-color: #dce9f2;
#   color: #000000;
# }
# #T_9759d_row2_col12 {
#   background-color: #5c0459;
#   color: #f1f1f1;
# }
# #T_9759d_row2_col20 {
#   background-color: #8c6ab1;
#   color: #f1f1f1;
# }
# #T_9759d_row2_col28 {
#   background-color: #bfd3e6;
#   color: #000000;
# }
# #T_9759d_row3_col0 {
#   background-color: #bacfe4;
#   color: #000000;
# }
# #T_9759d_row3_col5, #T_9759d_row4_col32, #T_9759d_row4_col34 {
#   background-color: #b5cce3;
#   color: #000000;
# }
# #T_9759d_row3_col12 {
#   background-color: #b3cbe2;
#   color: #000000;
# }
# #T_9759d_row3_col18 {
#   background-color: #cadbeb;
#   color: #000000;
# }
# #T_9759d_row3_col19 {
#   background-color: #6c0968;
#   color: #f1f1f1;
# }
# #T_9759d_row3_col31 {
#   background-color: #852d90;
#   color: #f1f1f1;
# }
# #T_9759d_row4_col3 {
#   background-color: #b7cee3;
#   color: #000000;
# }
# #T_9759d_row4_col18 {
#   background-color: #a4c0dc;
#   color: #000000;
# }
# #T_9759d_row4_col19 {
#   background-color: #8c69b0;
#   color: #f1f1f1;
# }
# #T_9759d_row4_col23 {
#   background-color: #e8f1f7;
#   color: #000000;
# }
# #T_9759d_row4_col31 {
#   background-color: #ccddec;
#   color: #000000;
# }
# </style>
# <table id="T_9759d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9759d_level0_col0" class="col_heading level0 col0" >Age</th>
#       <th id="T_9759d_level0_col1" class="col_heading level0 col1" >Attrition</th>
#       <th id="T_9759d_level0_col2" class="col_heading level0 col2" >BusinessTravel</th>
#       <th id="T_9759d_level0_col3" class="col_heading level0 col3" >DailyRate</th>
#       <th id="T_9759d_level0_col4" class="col_heading level0 col4" >Department</th>
#       <th id="T_9759d_level0_col5" class="col_heading level0 col5" >DistanceFromHome</th>
#       <th id="T_9759d_level0_col6" class="col_heading level0 col6" >Education</th>
#       <th id="T_9759d_level0_col7" class="col_heading level0 col7" >EducationField</th>
#       <th id="T_9759d_level0_col8" class="col_heading level0 col8" >EmployeeCount</th>
#       <th id="T_9759d_level0_col9" class="col_heading level0 col9" >EmployeeNumber</th>
#       <th id="T_9759d_level0_col10" class="col_heading level0 col10" >EnvironmentSatisfaction</th>
#       <th id="T_9759d_level0_col11" class="col_heading level0 col11" >Gender</th>
#       <th id="T_9759d_level0_col12" class="col_heading level0 col12" >HourlyRate</th>
#       <th id="T_9759d_level0_col13" class="col_heading level0 col13" >JobInvolvement</th>
#       <th id="T_9759d_level0_col14" class="col_heading level0 col14" >JobLevel</th>
#       <th id="T_9759d_level0_col15" class="col_heading level0 col15" >JobRole</th>
#       <th id="T_9759d_level0_col16" class="col_heading level0 col16" >JobSatisfaction</th>
#       <th id="T_9759d_level0_col17" class="col_heading level0 col17" >MaritalStatus</th>
#       <th id="T_9759d_level0_col18" class="col_heading level0 col18" >MonthlyIncome</th>
#       <th id="T_9759d_level0_col19" class="col_heading level0 col19" >MonthlyRate</th>
#       <th id="T_9759d_level0_col20" class="col_heading level0 col20" >NumCompaniesWorked</th>
#       <th id="T_9759d_level0_col21" class="col_heading level0 col21" >Over18</th>
#       <th id="T_9759d_level0_col22" class="col_heading level0 col22" >OverTime</th>
#       <th id="T_9759d_level0_col23" class="col_heading level0 col23" >PercentSalaryHike</th>
#       <th id="T_9759d_level0_col24" class="col_heading level0 col24" >PerformanceRating</th>
#       <th id="T_9759d_level0_col25" class="col_heading level0 col25" >RelationshipSatisfaction</th>
#       <th id="T_9759d_level0_col26" class="col_heading level0 col26" >StandardHours</th>
#       <th id="T_9759d_level0_col27" class="col_heading level0 col27" >StockOptionLevel</th>
#       <th id="T_9759d_level0_col28" class="col_heading level0 col28" >TotalWorkingYears</th>
#       <th id="T_9759d_level0_col29" class="col_heading level0 col29" >TrainingTimesLastYear</th>
#       <th id="T_9759d_level0_col30" class="col_heading level0 col30" >WorkLifeBalance</th>
#       <th id="T_9759d_level0_col31" class="col_heading level0 col31" >YearsAtCompany</th>
#       <th id="T_9759d_level0_col32" class="col_heading level0 col32" >YearsInCurrentRole</th>
#       <th id="T_9759d_level0_col33" class="col_heading level0 col33" >YearsSinceLastPromotion</th>
#       <th id="T_9759d_level0_col34" class="col_heading level0 col34" >YearsWithCurrManager</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9759d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9759d_row0_col0" class="data row0 col0" >41</td>
#       <td id="T_9759d_row0_col1" class="data row0 col1" >Yes</td>
#       <td id="T_9759d_row0_col2" class="data row0 col2" >Travel_Rarely</td>
#       <td id="T_9759d_row0_col3" class="data row0 col3" >1102</td>
#       <td id="T_9759d_row0_col4" class="data row0 col4" >Sales</td>
#       <t

# %% [markdown]
# For each employee, we observe the following 35 variables:
# * `Age` : Age in years of the employee
# * `Attrition` : People who people leave
# * `BusinessTravel` : How often an employee embark on a job related travel
# * `DailyRate` : Daily rate at which an employee is paid
# * `Department` : Department where the employee works
# * `DistanceFromHome` : Distance an employee travels from home to work
# * `Education` : Level of education of the employee
# * `EducationField` : What field the employee studied in school
# * `EmployeeCount` : Count of employee
# * `EmployeeNumber` : EMployee number
# * `EnvironmentSatisfaction` : Employee environment satisfaction
# * `Gender` : Gender of the employee
# * `HourlyRate` : Hourly rate of pay of the employee
# * `JobInvolvement` : Employee job involvement ratings
# * `JobLevel` : Employee Job level
# * `JobRole` : Employee Job role
# * `JobSatisfaction` : Employee Job Staisfaction
# * `MaritalStatus` : Employee Marital Status
# * `MonthlyIncome` : Employee monthly income
# * `MonthlyRate` : Employee Monthly rate
# * `NumCompaniesWorked` : Number of companies worked
# * `Over18` : Age over 18 years
# * `OverTime` : Work overtime
# * `PercentSalaryHike` : Salary increment in Percentages
# * `PerformanceRating` : Performance rating
# * `RelationshipSatisfaction` : Relationship satisfaction
# * `StandardHours` : Employee standard hours worked
# * `StockOptionLevel` : Stock options level
# * `TotalWorkingYears` : Total working hours
# * `TrainingTimesLastYear` : Total working years
# * `WorkLifeBalance` : Work life balance rating
# * `YearsAtCompany` : Years at the company
# * `YearsInCurrentRole` : Years in current role
# * `YearsSinceLastPromotion` : Years since last promotion
# * `YearsWithCurrManager` : Years with current manager

# %% [markdown]
# ##### <span style="color:purple"> **Question:** How many employees are we looking at? </span>

# %%
### TO BE COMPLETED ###
print(len(data))
# Out:
# 1470

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ##### <span style="color:purple"> **Todo:** Check data quality.</span>
#
# 1. Does this dataset contain duplicate rows?
# 2. How many distinct (unique) values does each variable take?
# 3. How many empty cells are there in each column?
# 4. How are the variables encoded? What type?

# %%
### TO BE COMPLETED ###
print('Number of duplicated lines:', data.duplicated().sum())
print('')

df = pd.DataFrame({
    'Unique':data.nunique(),
    'Null':data.isna().sum(),
    'NullPercent':data.isna().sum() / len(data),
    'Type':data.dtypes.values
})
display(df)
# Out:
# Number of duplicated lines: 0

# %%
# %load solutions/data_quality.py
print('Number of duplicated lines:', data.duplicated().sum())
print('')

df = pd.DataFrame({
    'Unique':data.nunique(),
    'Null':data.isna().sum(),
    'NullPercent':data.isna().sum() / len(data),
    'Type':data.dtypes.values
})
display(df)
# Out:
# Number of duplicated lines: 0
#                           Unique  Null  NullPercent    Type
# Age                           43     0          0.0   int64
# Attrition                      2     0          0.0  object
# BusinessTravel                 3     0          0.0  object
# DailyRate                    886     0          0.0   int64
# Department                     3     0          0.0  object
# DistanceFromHome              29     0          0.0   int64
# Education                      5     0          0.0   int64
# EducationField                 6     0          0.0  object
# EmployeeCount                  1     0          0.0   int64
# EmployeeNumber              1470     0          0.0   int64
# EnvironmentSatisfaction        4     0          0.0   int64
# Gender                         2     0          0.0  object
# HourlyRate                    71     0          0.0   int64
# JobInvolvement                 4     0          0.0   int64
# JobLevel                       5     0          0.0   int64
# JobRole                        9     0          0.0  object
# JobSatisfaction                4     0          0.0   int64
# MaritalStatus                  3     0          0.0  object
# MonthlyIncome               1349     0          0.0   int64
# MonthlyRate                 1427     0          0.0   int64
# NumCompaniesWorked            10     0          0.0   int64
# Over18                         1     0          0.0  object
# OverTime                       2     0          0.0  object
# PercentSalaryHike             15     0          0.0   int64
# PerformanceRating              2     0          0.0   int64
# RelationshipSatisfaction       4     0          0.0   int64
# StandardHours                  1     0          0.0   int64
# StockOptionLevel               4     0          0.0   int64
# TotalWorkingYears             40     0          0.0   int64
# TrainingTimesLastYear          7     0          0.0   int64
# WorkLifeBalance                4     0          0.0   int64
# YearsAtCompany                37     0          0.0   int64
# YearsInCurrentRole            19     0          0.0   int64
# YearsSinceLastPromotion       16     0          0.0   int64
# YearsWithCurrManager          18     0          0.0   int64

# %% [markdown]
# > Comments. il ne manque aucune donnée.

# %% [markdown]
# ##### <span style="color:purple"> **Todo:** Remove unnecessary columns.</span>
#
# Dropping columns that have:
# - Only _one_ inside it that doesn't contribute to the analysis
# - Columns that contain _index_ value
#
# Use pandas [`drop`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.drop.html) function.

# %%
### TO BE COMPLETED ###
data = data.drop(['EmployeeCount', 'Over18', 'StandardHours', 'EmployeeNumber'], axis=1) #axis=1 pour supprimer des colonnes (0 pour des lignes)
display( data.head().style.background_gradient(cmap='BuPu') )
# Out:
# <style type="text/css">
# #T_7610c_row0_col0 {
#   background-color: #8c68af;
#   color: #f1f1f1;
# }
# #T_7610c_row0_col3 {
#   background-color: #88449e;
#   color: #f1f1f1;
# }
# #T_7610c_row0_col5, #T_7610c_row0_col20, #T_7610c_row0_col21, #T_7610c_row0_col22, #T_7610c_row0_col23, #T_7610c_row0_col25, #T_7610c_row0_col26, #T_7610c_row0_col29, #T_7610c_row1_col3, #T_7610c_row1_col6, #T_7610c_row1_col11, #T_7610c_row1_col14, #T_7610c_row1_col18, #T_7610c_row2_col11, #T_7610c_row2_col12, #T_7610c_row2_col16, #T_7610c_row2_col17, #T_7610c_row2_col21, #T_7610c_row2_col23, #T_7610c_row2_col27, #T_7610c_row2_col28, #T_7610c_row2_col29, #T_7610c_row2_col30, #T_7610c_row3_col12, #T_7610c_row3_col18, #T_7610c_row3_col20, #T_7610c_row3_col21, #T_7610c_row3_col23, #T_7610c_row3_col30, #T_7610c_row4_col0, #T_7610c_row4_col6, #T_7610c_row4_col8, #T_7610c_row4_col10, #T_7610c_row4_col12, #T_7610c_row4_col14, #T_7610c_row4_col21, #T_7610c_row4_col24 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_7610c_row0_col6, #T_7610c_row0_col8, #T_7610c_row1_col29, #T_7610c_row2_col6, #T_7610c_row2_col20, #T_7610c_row2_col22 {
#   background-color: #a9c4de;
#   color: #000000;
# }
# #T_7610c_row0_col10, #T_7610c_row0_col11, #T_7610c_row0_col12, #T_7610c_row0_col14, #T_7610c_row0_col16, #T_7610c_row1_col0, #T_7610c_row1_col5, #T_7610c_row1_col12, #T_7610c_row1_col17, #T_7610c_row1_col20, #T_7610c_row1_col21, #T_7610c_row1_col22, #T_7610c_row1_col23, #T_7610c_row1_col24, #T_7610c_row1_col25, #T_7610c_row1_col26, #T_7610c_row1_col27, #T_7610c_row1_col28, #T_7610c_row1_col30, #T_7610c_row2_col8, #T_7610c_row2_col25, #T_7610c_row2_col26, #T_7610c_row3_col3, #T_7610c_row3_col6, #T_7610c_row3_col8, #T_7610c_row3_col11, #T_7610c_row3_col25, #T_7610c_row3_col26, #T_7610c_row3_col28, #T_7610c_row3_col29, #T_7610c_row4_col11, #T_7610c_row4_col18, #T_7610c_row4_col22, #T_7610c_row4_col23, #T_7610c_row4_col25, #T_7610c_row4_col26 {
#   background-color: #4d004b;
#   color: #f1f1f1;
# }
# #T_7610c_row0_col17 {
#   background-color: #873d9a;
#   color: #f1f1f1;
# }
# #T_7610c_row0_col18 {
#   background-color: #800f7b;
#   color: #f1f1f1;
# }
# #T_7610c_row0_col24, #T_7610c_row2_col14, #T_7610c_row3_col14, #T_7610c_row3_col24 {
#   background-color: #8c95c6;
#   color: #f1f1f1;
# }
# #T_7610c_row0_col27 {
#   background-color: #8c74b5;
#   color: #f1f1f1;
# }
# #T_7610c_row0_col28 {
#   background-color: #8c7dba;
#   color: #f1f1f1;
# }
# #T_7610c_row0_col30 {
#   background-color: #894da3;
#   color: #f1f1f1;
# }
# #T_7610c_row1_col8, #T_7610c_row3_col22, #T_7610c_row4_col29 {
#   background-color: #8b5daa;
#   color: #f1f1f1;
# }
# #T_7610c_row1_col10 {
#   background-color: #9cb8d8;
#   color: #000000;
# }
# #T_7610c_row1_col16 {
#   background-color: #863595;
#   color: #f1f1f1;
# }
# #T_7610c_row2_col0 {
#   background-color: #92a4cd;
#   color: #f1f1f1;
# }
# #T_7610c_row2_col3 {
#   background-color: #540251;
#   color: #f1f1f1;
# }
# #T_7610c_row2_col5, #T_7610c_row4_col5 {
#   background-color: #dce9f2;
#   color: #000000;
# }
# #T_7610c_row2_col10 {
#   background-color: #5c0459;
#   color: #f1f1f1;
# }
# #T_7610c_row2_col18 {
#   background-color: #8c6ab1;
#   color: #f1f1f1;
# }
# #T_7610c_row2_col24 {
#   background-color: #bfd3e6;
#   color: #000000;
# }
# #T_7610c_row3_col0 {
#   background-color: #bacfe4;
#   color: #000000;
# }
# #T_7610c_row3_col5, #T_7610c_row4_col28, #T_7610c_row4_col30 {
#   background-color: #b5cce3;
#   color: #000000;
# }
# #T_7610c_row3_col10 {
#   background-color: #b3cbe2;
#   color: #000000;
# }
# #T_7610c_row3_col16 {
#   background-color: #cadbeb;
#   color: #000000;
# }
# #T_7610c_row3_col17 {
#   background-color: #6c0968;
#   color: #f1f1f1;
# }
# #T_7610c_row3_col27 {
#   background-color: #852d90;
#   color: #f1f1f1;
# }
# #T_7610c_row4_col3 {
#   background-color: #b7cee3;
#   color: #000000;
# }
# #T_7610c_row4_col16 {
#   background-color: #a4c0dc;
#   color: #000000;
# }
# #T_7610c_row4_col17 {
#   background-color: #8c69b0;
#   color: #f1f1f1;
# }
# #T_7610c_row4_col20 {
#   background-color: #e8f1f7;
#   color: #000000;
# }
# #T_7610c_row4_col27 {
#   background-color: #ccddec;
#   color: #000000;
# }
# </style>
# <table id="T_7610c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7610c_level0_col0" class="col_heading level0 col0" >Age</th>
#       <th id="T_7610c_level0_col1" class="col_heading level0 col1" >Attrition</th>
#       <th id="T_7610c_level0_col2" class="col_heading level0 col2" >BusinessTravel</th>
#       <th id="T_7610c_level0_col3" class="col_heading level0 col3" >DailyRate</th>
#       <th id="T_7610c_level0_col4" class="col_heading level0 col4" >Department</th>
#       <th id="T_7610c_level0_col5" class="col_heading level0 col5" >DistanceFromHome</th>
#       <th id="T_7610c_level0_col6" class="col_heading level0 col6" >Education</th>
#       <th id="T_7610c_level0_col7" class="col_heading level0 col7" >EducationField</th>
#       <th id="T_7610c_level0_col8" class="col_heading level0 col8" >EnvironmentSatisfaction</th>
#       <th id="T_7610c_level0_col9" class="col_heading level0 col9" >Gender</th>
#       <th id="T_7610c_level0_col10" class="col_heading level0 col10" >HourlyRate</th>
#       <th id="T_7610c_level0_col11" class="col_heading level0 col11" >JobInvolvement</th>
#       <th id="T_7610c_level0_col12" class="col_heading level0 col12" >JobLevel</th>
#       <th id="T_7610c_level0_col13" class="col_heading level0 col13" >JobRole</th>
#       <th id="T_7610c_level0_col14" class="col_heading level0 col14" >JobSatisfaction</th>
#       <th id="T_7610c_level0_col15" class="col_heading level0 col15" >MaritalStatus</th>
#       <th id="T_7610c_level0_col16" class="col_heading level0 col16" >MonthlyIncome</th>
#       <th id="T_7610c_level0_col17" class="col_heading level0 col17" >MonthlyRate</th>
#       <th id="T_7610c_level0_col18" class="col_heading level0 col18" >NumCompaniesWorked</th>
#       <th id="T_7610c_level0_col19" class="col_heading level0 col19" >OverTime</th>
#       <th id="T_7610c_level0_col20" class="col_heading level0 col20" >PercentSalaryHike</th>
#       <th id="T_7610c_level0_col21" class="col_heading level0 col21" >PerformanceRating</th>
#       <th id="T_7610c_level0_col22" class="col_heading level0 col22" >RelationshipSatisfaction</th>
#       <th id="T_7610c_level0_col23" class="col_heading level0 col23" >StockOptionLevel</th>
#       <th id="T_7610c_level0_col24" class="col_heading level0 col24" >TotalWorkingYears</th>
#       <th id="T_7610c_level0_col25" class="col_heading level0 col25" >TrainingTimesLastYear</th>
#       <th id="T_7610c_level0_col26" class="col_heading level0 col26" >WorkLifeBalance</th>
#       <th id="T_7610c_level0_col27" class="col_heading level0 col27" >YearsAtCompany</th>
#       <th id="T_7610c_level0_col28" class="col_heading level0 col28" >YearsInCurrentRole</th>
#       <th id="T_7610c_level0_col29" class="col_heading level0 col29" >YearsSinceLastPromotion</th>
#       <th id="T_7610c_level0_col30" class="col_heading level0 col30" >YearsWithCurrManager</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7610c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7610c_row0_col0" class="data row0 col0" >41</td>
#       <td id="T_7610c_row0_col1" class="data row0 col1" >Yes</td>
#       <td id="T_7610c_row0_col2" class="data row0 col2" >Travel_Rarely</td>
#       <td id="T_7610c_row0_col3" class="data row0 col3" >1102</td>
#       <td id="T_7610c_row0_col4" class="data row0 col4" >Sales</td>
#       <td id="T_7610c_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_7610c_row0_col6" class="data row0 col6" >2</td>
#       <td id="T_7610c_row0_col7" class="data row0 col7" >Life Sciences</td>
#       <td id="T_7610c_row0_col8" class="data row0 col8" >2</td>
#       <td id="T_7610c_row0_col9" class="data row0 col9" >Female</td>
#       <td id="T_7610c_row0_col10" class="data row0 col10" >94</td>
#       <td id="T_7610c_row0_col11" class="data row0 col11" >3</td>
#       <td id="T_7610c_row0_col12" class="data row0 col12" >2</td>
#       <td id="T_7610c_row0_col13" class="data row0 col13" >Sales Executive</td>
#       <td id="T_7610c_row0_col14" class="data row0 col14" >4</td>
#       <td id="T_7610c_row0_col15" cl

# %%
# %load solutions/data_drop.py

# %% [markdown]
# Consider two dataframes, `num` and `cat`, containing _quantitative_ and _qualitative_ data respectively.

# %%
num = data.select_dtypes(exclude='O')
display(num.head())
# Out:
#    Age  DailyRate  DistanceFromHome  Education  EnvironmentSatisfaction  \
# 0   41       1102                 1          2                        2
# 1   49        279                 8          1                        3
# 2   37       1373                 2          2                        4
# 3   33       1392                 3          4                        4
# 4   27        591                 2          1                        1
#
#    HourlyRate  JobInvolvement  JobLevel  JobSatisfaction  MonthlyIncome  ...  \
# 0          94               3         2                4           5993  ...
# 1          61               2         2                2           5130  ...
# 2          92               2         1                3           2090  ...
# 3          56               3         1                3           2909  ...
# 4          40               3         1                2           3468  ...
#
#    PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# 0                  3                         1                 0
# 1                  4                         4                 1
# 2                  3                         2                 0
# 3                  3                         3                 0
# 4                  3                         4                 1
#
#    TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0                1               6
# 1                 10                      3                3              10
# 2                  7                      3                3               0
# 3                  8                      3                3               8
# 4                  6                      3                3               2
#
#    YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                   4                        0                     5
# 1                   7                        1                     7
# 2                   0                        0                     0
# 3                   7                        3                     0
# 4                   2                        2                     2
#
# [5 rows x 23 columns]

# %%
cat = data.select_dtypes(include='O')
display(cat.head())
# Out:
#   Attrition     BusinessTravel              Department EducationField  Gender  \
# 0       Yes      Travel_Rarely                   Sales  Life Sciences  Female
# 1        No  Travel_Frequently  Research & Development  Life Sciences    Male
# 2       Yes      Travel_Rarely  Research & Development          Other    Male
# 3        No  Travel_Frequently  Research & Development  Life Sciences  Female
# 4        No      Travel_Rarely  Research & Development        Medical    Male
#
#                  JobRole MaritalStatus OverTime
# 0        Sales Executive        Single      Yes
# 1     Research Scientist       Married       No
# 2  Laboratory Technician        Single      Yes
# 3     Research Scientist       Married      Yes
# 4  Laboratory Technician       Married       No

# %% [markdown]
# ##### <span style="color:purple"> **Question:**  What is the proportion of qualitative data in this dataset? Of quantitative data?</span>

# %%
### TO BE COMPLETED ###
print('Quantitative data:', round(100*num.shape[1]/data.shape[1],2), '%')
print('Qualitative data:', round(100*cat.shape[1]/data.shape[1],2), '%')
# Out:
# Quantitative data: 74.19 %
# Qualitative data: 25.81 %

# %%
# %load solutions/data_proportion.py

# %% [markdown]
# ##### <span style="color:purple"> **Todo:** For each variable, display its basic statistical descriptors: variable, mean, quantiles, _etc._</span>

# %%
### TO BE COMPLETED ###
display( data.describe().T.style.background_gradient(cmap='BuPu') ) #T pour la trasnposée
# Out:
# <style type="text/css">
# #T_a824e_row0_col0, #T_a824e_row0_col1, #T_a824e_row0_col2, #T_a824e_row0_col4, #T_a824e_row0_col5, #T_a824e_row0_col6, #T_a824e_row0_col7, #T_a824e_row1_col0, #T_a824e_row2_col0, #T_a824e_row2_col1, #T_a824e_row2_col2, #T_a824e_row2_col3, #T_a824e_row2_col4, #T_a824e_row2_col5, #T_a824e_row2_col6, #T_a824e_row2_col7, #T_a824e_row3_col0, #T_a824e_row3_col1, #T_a824e_row3_col2, #T_a824e_row3_col3, #T_a824e_row3_col4, #T_a824e_row3_col5, #T_a824e_row3_col6, #T_a824e_row3_col7, #T_a824e_row4_col0, #T_a824e_row4_col1, #T_a824e_row4_col2, #T_a824e_row4_col3, #T_a824e_row4_col4, #T_a824e_row4_col5, #T_a824e_row4_col6, #T_a824e_row4_col7, #T_a824e_row5_col0, #T_a824e_row5_col2, #T_a824e_row5_col7, #T_a824e_row6_col0, #T_a824e_row6_col1, #T_a824e_row6_col2, #T_a824e_row6_col3, #T_a824e_row6_col4, #T_a824e_row6_col5, #T_a824e_row6_col6, #T_a824e_row6_col7, #T_a824e_row7_col0, #T_a824e_row7_col1, #T_a824e_row7_col2, #T_a824e_row7_col3, #T_a824e_row7_col4, #T_a824e_row7_col5, #T_a824e_row7_col6, #T_a824e_row7_col7, #T_a824e_row8_col0, #T_a824e_row8_col1, #T_a824e_row8_col2, #T_a824e_row8_col3, #T_a824e_row8_col4, #T_a824e_row8_col5, #T_a824e_row8_col6, #T_a824e_row8_col7, #T_a824e_row9_col0, #T_a824e_row10_col0, #T_a824e_row11_col0, #T_a824e_row11_col1, #T_a824e_row11_col2, #T_a824e_row11_col3, #T_a824e_row11_col4, #T_a824e_row11_col5, #T_a824e_row11_col6, #T_a824e_row11_col7, #T_a824e_row12_col0, #T_a824e_row12_col1, #T_a824e_row12_col2, #T_a824e_row12_col4, #T_a824e_row12_col5, #T_a824e_row12_col6, #T_a824e_row12_col7, #T_a824e_row13_col0, #T_a824e_row13_col1, #T_a824e_row13_col2, #T_a824e_row13_col3, #T_a824e_row13_col4, #T_a824e_row13_col5, #T_a824e_row13_col6, #T_a824e_row13_col7, #T_a824e_row14_col0, #T_a824e_row14_col1, #T_a824e_row14_col2, #T_a824e_row14_col3, #T_a824e_row14_col4, #T_a824e_row14_col5, #T_a824e_row14_col6, #T_a824e_row14_col7, #T_a824e_row15_col0, #T_a824e_row15_col1, #T_a824e_row15_col2, #T_a824e_row15_col3, #T_a824e_row15_col4, #T_a824e_row15_col5, #T_a824e_row15_col6, #T_a824e_row15_col7, #T_a824e_row16_col0, #T_a824e_row16_col1, #T_a824e_row16_col2, #T_a824e_row16_col3, #T_a824e_row16_col4, #T_a824e_row16_col5, #T_a824e_row16_col6, #T_a824e_row16_col7, #T_a824e_row17_col0, #T_a824e_row17_col1, #T_a824e_row17_col2, #T_a824e_row17_col3, #T_a824e_row17_col4, #T_a824e_row17_col5, #T_a824e_row17_col6, #T_a824e_row17_col7, #T_a824e_row18_col0, #T_a824e_row18_col1, #T_a824e_row18_col2, #T_a824e_row18_col3, #T_a824e_row18_col4, #T_a824e_row18_col5, #T_a824e_row18_col6, #T_a824e_row18_col7, #T_a824e_row19_col0, #T_a824e_row19_col1, #T_a824e_row19_col2, #T_a824e_row19_col3, #T_a824e_row19_col4, #T_a824e_row19_col5, #T_a824e_row19_col6, #T_a824e_row19_col7, #T_a824e_row20_col0, #T_a824e_row20_col1, #T_a824e_row20_col2, #T_a824e_row20_col3, #T_a824e_row20_col4, #T_a824e_row20_col5, #T_a824e_row20_col6, #T_a824e_row20_col7, #T_a824e_row21_col0, #T_a824e_row21_col1, #T_a824e_row21_col2, #T_a824e_row21_col3, #T_a824e_row21_col4, #T_a824e_row21_col5, #T_a824e_row21_col6, #T_a824e_row21_col7, #T_a824e_row22_col0, #T_a824e_row22_col1, #T_a824e_row22_col2, #T_a824e_row22_col3, #T_a824e_row22_col4, #T_a824e_row22_col5, #T_a824e_row22_col6, #T_a824e_row22_col7 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_a824e_row0_col3 {
#   background-color: #f6fbfc;
#   color: #000000;
# }
# #T_a824e_row1_col1, #T_a824e_row1_col2, #T_a824e_row1_col4, #T_a824e_row1_col5, #T_a824e_row1_col6, #T_a824e_row1_col7 {
#   background-color: #edf5f9;
#   color: #000000;
# }
# #T_a824e_row1_col3 {
#   background-color: #eef6fa;
#   color: #000000;
# }
# #T_a824e_row5_col1, #T_a824e_row5_col4, #T_a824e_row5_col5, #T_a824e_row5_col6, #T_a824e_row12_col3 {
#   background-color: #f6fbfd;
#   color: #000000;
# }
# #T_a824e_row5_col3 {
#   background-color: #f5fafc;
#   color: #000000;
# }
# #T_a824e_row9_col1 {
#   background-color: #92a4cd;
#   color: #f1f1f1;
# }
# #T_a824e_row9_col2 {
#   background-color: #8b5eab;
#   color: #f1f1f1;
# }
# #T_a824e_row9_col3 {
#   background-color: #8f9bc9;
#   color: #f1f1f1;
# }
# #T_a824e_row9_col4 {
#   background-color: #a2bfdb;
#   color: #000000;
# }
# #T_a824e_row9_col5 {
#   background-color: #a6c2dd;
#   color: #000000;
# }
# #T_a824e_row9_col6 {
#   background-color: #99b2d5;
#   color: #000000;
# }
# #T_a824e_row9_col7 {
#   background-color: #88449e;
#   color: #f1f1f1;
# }
# #T_a824e_row10_col1, #T_a824e_row10_col2, #T_a824e_row10_col3, #T_a824e_row10_col4, #T_a824e_row10_col5, #T_a824e_row10_col6, #T_a824e_row10_col7 {
#   background-color: #4d004b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a824e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a824e_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_a824e_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_a824e_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_a824e_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_a824e_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_a824e_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_a824e_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_a824e_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a824e_level0_row0" class="row_heading level0 row0" >Age</th>
#       <td id="T_a824e_row0_col0" class="data row0 col0" >1470.000000</td>
#       <td id="T_a824e_row0_col1" class="data row0 col1" >36.923810</td>
#       <td id="T_a824e_row0_col2" class="data row0 col2" >9.135373</td>
#       <td id="T_a824e_row0_col3" class="data row0 col3" >18.000000</td>
#       <td id="T_a824e_row0_col4" class="data row0 col4" >30.000000</td>
#       <td id="T_a824e_row0_col5" class="data row0 col5" >36.000000</td>
#       <td id="T_a824e_row0_col6" class="data row0 col6" >43.000000</td>
#       <td id="T_a824e_row0_col7" class="data row0 col7" >60.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a824e_level0_row1" class="row_heading level0 row1" >DailyRate</th>
#       <td id="T_a824e_row1_col0" class="data row1 col0" >1470.000000</td>
#       <td id="T_a824e_row1_col1" class="data row1 col1" >802.485714</td>
#       <td id="T_a824e_row1_col2" class="data row1 col2" >403.509100</td>
#       <td id="T_a824e_row1_col3" class="data row1 col3" >102.000000</td>
#       <td id="T_a824e_row1_col4" class="data row1 col4" >465.000000</td>
#       <td id="T_a824e_row1_col5" class="data row1 col5" >802.000000</td>
#       <td id="T_a824e_row1_col6" class="data row1 col6" >1157.000000</td>
#       <td id="T_a824e_row1_col7" class="data row1 col7" >1499.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a824e_level0_row2" class="row_heading level0 row2" >DistanceFromHome</th>
#       <td id="T_a824e_row2_col0" class="data row2 col0" >1470.000000</td>
#       <td id="T_a824e_row2_col1" class="data row2 col1" >9.192517</td>
#       <td id="T_a824e_row2_col2" class="data row2 col2" >8.106864</td>
#       <td id="T_a824e_row2_col3" class="data row2 col3" >1.000000</td>
#       <td id="T_a824e_row2_col4" class="data row2 col4" >2.000000</td>
#       <td id="T_a824e_row2_col5" class="data row2 col5" >7.000000</td>
#       <td id="T_a824e_row2_col6" class="data row2 col6" >14.000000</td>
#       <td id="T_a824e_row2_col7" class="data row2 col7" >29.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a824e_level0_row3" class="row_heading level0 row3" >Education</th>
#       <td id="T_a824e_row3_col0" class="data row3 col0" >1470.000000</td>
#       <td id="T_a824e_row3_col1" class="data row3 col1" >2.912925</td>
#       <td id="T_a824e_row3_col2" class="data row3 col2" >1.024165</td>
#       <td id="T_a824e_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_a824e_row3_col4" class="data row3 col4" >2.000000</td>
#       <td id="T_a824e_row3_col5" class="data row3 col5" >3.000000</td>
#       <td id="T_a824e_row3_col6" class="data row3 col6" >4.000000</td>
#       <td id="T_a824e_row3_col7" class="data row3 col7" >5.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a824e_l

# %%
# %load solutions/stat_summary.py
print( data.describe().T )
display( data.describe().T.style.background_gradient(cmap='BuPu') )
# Out:
#                            count          mean          std     min     25%  \
# Age                       1470.0     36.923810     9.135373    18.0    30.0
# DailyRate                 1470.0    802.485714   403.509100   102.0   465.0
# DistanceFromHome          1470.0      9.192517     8.106864     1.0     2.0
# Education                 1470.0      2.912925     1.024165     1.0     2.0
# EnvironmentSatisfaction   1470.0      2.721769     1.093082     1.0     2.0
# HourlyRate                1470.0     65.891156    20.329428    30.0    48.0
# JobInvolvement            1470.0      2.729932     0.711561     1.0     2.0
# JobLevel                  1470.0      2.063946     1.106940     1.0     1.0
# JobSatisfaction           1470.0      2.728571     1.102846     1.0     2.0
# MonthlyIncome             1470.0   6502.931293  4707.956783  1009.0  2911.0
# MonthlyRate               1470.0  14313.103401  7117.786044  2094.0  8047.0
# NumCompaniesWorked        1470.0      2.693197     2.498009     0.0     1.0
# PercentSalaryHike         1470.0     15.209524     3.659938    11.0    12.0
# PerformanceRating         1470.0      3.153741     0.360824     3.0     3.0
# RelationshipSatisfaction  1470.0      2.712245     1.081209     1.0     2.0
# StockOptionLevel          1470.0      0.793878     0.852077     0.0     0.0
# TotalWorkingYears         1470.0     11.279592     7.780782     0.0     6.0
# TrainingTimesLastYear     1470.0      2.799320     1.289271     0.0     2.0
# WorkLifeBalance           1470.0      2.761224     0.706476     1.0     2.0
# YearsAtCompany            1470.0      7.008163     6.126525     0.0     3.0
# YearsInCurrentRole        1470.0      4.229252     3.623137     0.0     2.0
# YearsSinceLastPromotion   1470.0      2.187755     3.222430     0.0     0.0
# YearsWithCurrManager      1470.0      4.123129     3.568136     0.0     2.0
#
#                               50%       75%      max
# Age                          36.0     43.00     60.0
# DailyRate                   802.0   1157.00   1499.0
# DistanceFromHome              7.0     14.00     29.0
# Education                     3.0      4.00      5.0
# EnvironmentSatisfaction       3.0      4.00      4.0
# HourlyRate                   66.0     83.75    100.0
# JobInvolvement                3.0      3.00      4.0
# JobLevel                      2.0      3.00      5.0
# JobSatisfaction               3.0      4.00      4.0
# MonthlyIncome              4919.0   8379.00  19999.0
# MonthlyRate               14235.5  20461.50  26999.0
# NumCompaniesWorked            2.0      4.00      9.0
# PercentSalaryHike            14.0     18.00     25.0
# PerformanceRating             3.0      3.00      4.0
# RelationshipSatisfaction      3.0      4.00      4.0
# StockOptionLevel              1.0      1.00      3.0
# TotalWorkingYears            10.0     15.00     40.0
# TrainingTimesLastYear         3.0      3.00      6.0
# WorkLifeBalance               3.0      3.00      4.0
# YearsAtCompany                5.0      9.00     40.0
# YearsInCurrentRole            3.0      7.00     18.0
# YearsSinceLastPromotion       1.0      3.00     15.0
# YearsWithCurrManager          3.0      7.00     17.0
# <style type="text/css">
# #T_c7618_row0_col0, #T_c7618_row0_col1, #T_c7618_row0_col2, #T_c7618_row0_col4, #T_c7618_row0_col5, #T_c7618_row0_col6, #T_c7618_row0_col7, #T_c7618_row1_col0, #T_c7618_row2_col0, #T_c7618_row2_col1, #T_c7618_row2_col2, #T_c7618_row2_col3, #T_c7618_row2_col4, #T_c7618_row2_col5, #T_c7618_row2_col6, #T_c7618_row2_col7, #T_c7618_row3_col0, #T_c7618_row3_col1, #T_c7618_row3_col2, #T_c7618_row3_col3, #T_c7618_row3_col4, #T_c7618_row3_col5, #T_c7618_row3_col6, #T_c7618_row3_col7, #T_c7618_row4_col0, #T_c7618_row4_col1, #T_c7618_row4_col2, #T_c7618_row4_col3, #T_c7618_row4_col4, #T_c7618_row4_col5, #T_c7618_row4_col6, #T_c7618_row4_col7, #T_c7618_row5_col0, #T_c7618_row5_col2, #T_c7618_row5_col7, #T_c7618_row6_col0, #T_c7618_row6_col1, #T_c7618_row6_col2, #T_c7618_row6_col3, #T_c7618_row6_col4, #T_c7618_row6_col5, #T_c7618_row6_col6, #T_c7618_row6_col7, #T_c7618_row7_col0, #T_c7618_row7_col1, #T_c7618_row7_col2, #T_c7618_row7_col3, #T_c7618_row7_col4, #T_c7618_row7_col5, #T_c7618_row7_col6, #T_c7618_row7_col7, #T_c7618_row8_col0, #T_c7618_row8_col1, #T_c7618_row8_col2, #T_c7618_row8_col3, #T_c7618_row8_col4, #T_c7618_row8_col5, #T_c7618_row8_col6, #T_c7618_row8_col7, #T_c7618_row9_col0, #T_c7618_row10_col0, #T_c7618_row11_col0, #T_c7618_row11_col1, #T_c7618_row11_col2, #T_c7618_row11_col3, #T_c7618_row11_col4, #T_c7618_row11_col5, #T_c7618_row11_col6, #T_c7618_row11_col7, #T_c7618_row12_col0, #T_c7618_row12_col1, #T_c7618_row12_col2, #T_c7618_row12_col4, #T_c7618_row12_col5, #T_c7618_row12_col6, #T_c7618_row12_col7, #T_c7618_row13_col0, #T_c7618_row13_col1, #T_c7618_row13_col2, #T_c7618_row13_col3, #T_c7618_row13_col4, #T_c7618_row13_col5, #T_c7618_row13_col6, #T_c7618_row13_col7, #T_c7618_row14_col0, #T_c7618_row14_col1, #T_c7618_row14_col2, #T_c7618_row14_col3, #T_c7618_row14_col4, #T_c7618_row14_col5, #T_c7618_row14_col6, #T_c7618_row14_col7, #T_c7618_row15_col0, #T_c7618_row15_col1, #T_c7618_row15_col2, #T_c7618_row15_col3, #T_c7618_row15_col4, #T_c7618_row15_col5, #T_c7618_row15_col6, #T_c7618_row15_col7, #T_c7618_row16_col0, #T_c7618_row16_col1, #T_c7618_row16_col2, #T_c7618_row16_col3, #T_c7618_row16_col4, #T_c7618_row16_col5, #T_c7618_row16_col6, #T_c7618_row16_col7, #T_c7618_row17_col0, #T_c7618_row17_col1, #T_c7618_row17_col2, #T_c7618_row17_col3, #T_c7618_row17_col4, #T_c7618_row17_col5, #T_c7618_row17_col6, #T_c7618_row17_col7, #T_c7618_row18_col0, #T_c7618_row18_col1, #T_c7618_row18_col2, #T_c7618_row18_col3, #T_c7618_row18_col4, #T_c7618_row18_col5, #T_c7618_row18_col6, #T_c7618_row18_col7, #T_c7618_row19_col0, #T_c7618_row19_col1, #T_c7618_row19_col2, #T_c7618_row19_col3, #T_c7618_row19_col4, #T_c7618_row19_col5, #T_c7618_row19_col6, #T_c7618_row19_col7, #T_c7618_row20_col0, #T_c7618_row20_col1, #T_c7618_row20_col2, #T_c7618_row20_col3, #T_c7618_row20_col4, #T_c7618_row20_col5, #T_c7618_row20_col6, #T_c7618_row20_col7, #T_c7618_row21_col0, #T_c7618_row21_col1, #T_c7618_row21_col2, #T_c7618_row21_col3, #T_c7618_row21_col4, #T_c7618_row21_col5, #T_c7618_row21_col6, #T_c7618_row21_col7, #T_c7618_row22_col0, #T_c7618_row22_col1, #T_c7618_row22_col2, #T_c7618_row22_col3, #T_c7618_row22_col4, #T_c7618_row22_col5, #T_c7618_row22_col6, #T_c7618_row22_col7 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_c7618_row0_col3 {
#   background-color: #f6fbfc;
#   color: #000000;
# }
# #T_c7618_row1_col1, #T_c7618_row1_col2, #T_c7618_row1_col4, #T_c7618_row1_col5, #T_c7618_row1_col6, #T_c7618_row1_col7 {
#   background-color: #edf5f9;
#   color: #000000;
# }
# #T_c7618_row1_col3 {
#   background-color: #eef6fa;
#   color: #000000;
# }
# #T_c7618_row5_col1, #T_c7618_row5_col4, #T_c7618_row5_col5, #T_c7618_row5_col6, #T_c7618_row12_col3 {
#   background-color: #f6fbfd;
#   color: #000000;
# }
# #T_c7618_row5_col3 {
#   background-color: #f5fafc;
#   color: #000000;
# }
# #T_c7618_row9_col1 {
#   background-color: #92a4cd;
#   color: #f1f1f1;
# }
# #T_c7618_row9_col2 {
#   background-color: #8b5eab;
#   color: #f1f1f1;
# }
# #T_c7618_row9_col3 {
#   background-color: #8f9bc9;
#   color: #f1f1f1;
# }
# #T_c7618_row9_col4 {
#   background-color: #a2bfdb;
#   color: #000000;
# }
# #T_c7618_row9_col5 {
#   background-color: #a6c2dd;
#   color: #000000;
# }
# #T_c7618_row9_col6 {
#   background-color: #99b2d5;
#   color: #000000;
# }
# #T_c7618_row9_col7 {
#   background-color: #88449e;
#   color: #f1f1f1;
# }
# #T_c7618_row10_col1, #T_c7618_row10_col2, #T_c7618_row10_col3, #T_c7618_row10_col4, #T_c7618_row10_col5, #T_c7618_row10_col6, #T_c7618_row10_col7 {
#   background-color: #4d004b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c7618">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c7618_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_c7618_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_c7618_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_c7618_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_c7618_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_c7618_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_c7618_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_c7618_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c7618_level0_row0" class="row_heading level0 row0" >Age</th>
#       <td id="T_c7618_row0_col0" class="data row0 col0" >1470.000000</td>
#       <td id="T_c7618_row0_col1" class="data row0 col1" >36.923810</td>
#       <td id="T_c7618_row0_col2" class="data row0 col2" >9.135373</td>
#       <td id="T_c7618_row0_col3" class="data row0 col3" >18.000000</td>
#       <td id="T_c7618_row0_col4" class="data row0 col4" >30.000000</td>
#       <td id="T_c7618_row0_col5" class="data row0 col5" >36.000000</td>
#       <td id="T_c7618_row0_col6" class="data row0 col6" >43.000000</td>
#       <td id="T_c7618_row0_col7" class="data row0 col7" >60.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c7618_level0_row1" class="row_heading level0 row1" >DailyRate</th>
#       <td id="T_c7618_row1_col0" class="data row1 col0" >1470.000000</td>
#       <td id="T_c7618_row1_col1" class="data row1 col1" >802.485714</td>
#       <td id="T_c7618_row1_col2" class="data row1 col2" >403.509100</td>
#       <td id="T_c7618_row1_col3" class="data row1 col3" >102.000000</td>
#       <td id="T_c7618_row1_col4" class="data row1 col4" >465.000000</td>
#       <td id="T_c7618_row1_col5" class="data row1 col5" >802.000000</td>
#       <td id="T_c7618_row1_col6" class="data row1 col6" >1157.000000</td>
#       <td id="T_c7618_row1_col7" class="data row1 col7" >1499.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c7618_level0_row2" class="row_heading level0 row2" >DistanceFromHome</th>
#       <td id="T_c7618_row2_col0" class="data row2 col0" >1470.000000</td>
#       <td id="T_c7618_row2_col1" class="data row2 col1" >9.192517</td>
#       <td id="T_c7618_row2_col2" class="data row2 col2" >8.106864</td>
#       <td id="T_c7618_row2_col3" class="data row2 col3" >1.000000</td>
#       <td id="T_c7618_row2_col4" class="data row2 col4" >2.000000</td>
#       <td id="T_c7618_row2_col5" class="data row2 col5" >7.000000</td>
#       <td id="T_c7618_row2_col6" class="data row2 col6" >14.000000</td>
#       <td id="T_c7618_row2_col7" class="data row2 col7" >29.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c7618_level0_row3" class="row_heading level0 row3" >Education</th>
#       <td id="T_c7618_row3_col0" class="data row3 col0" >1470.000000</td>
#       <td id="T_c7618_row3_col1" class="data row3 col1" >2.912925</td>
#       <td id="T_c7618_row3_col2" class="data row3 col2" >1.024165</td>
#       <td id="T_c7618_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_c7618_row3_col4" class="data row3 col4" >2.000000</td>
#       <td id="T_c7618_row3_col5" class="data row3 col5" >3.000000</td>
#       <td id="T_c7618_row3_col6" class="data row3 col6" >4.000000</td>
#       <td id="T_c7618_row3_col7" class="data row3 col7" >5.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c7618_l

# %% [markdown]
# ## Correlation Analysis

# %% [markdown]
# ##### <span style="color:purple"> **Todo:** Assess the correlation between variables.</span>
#
# 1. Plot the Correlation Matrix between variables,
# 2. You can select columns with high correlation:

# %%
### TO BE COMPLETED ###
plt.figure(figsize=(18,9))

# correlation between columns
sns.heatmap(data.corr(numeric_only=True), annot=True, fmt='.1f')
plt.xticks(rotation=40)

plt.show()

# --- #

# strong correlation between columns
cols = ['Education','Age','MonthlyIncome','JobLevel','NumCompaniesWorked','TotalWorkingYears','YearsAtCompany',
       'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager']
sns.heatmap(data[cols].corr(), annot=True, fmt='.1f')
plt.xticks(rotation=40)
plt.show()

# %%
# %load solutions/data_correlation.py

# %% [markdown]
# ##### <span style="color:purple"> **Todo:** Draw a pairplot for the 5 highest correlation variable.</span>
#
# Color the observations according to their attribution.

# %%
### TO BE COMPLETED ###
cols = ['TotalWorkingYears', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'Attrition']

sns.pairplot(data[cols], hue = 'Attrition', palette={'Yes': 'mediumvioletred', 'No': 'cornflowerblue'})
plt.show()

[...]
# Out:
# [Ellipsis]

# %%
# %load solutions/data_pairplot.py
cols = ['TotalWorkingYears', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'Attrition']

sns.pairplot(data[cols], hue = 'Attrition', palette={'Yes': 'mediumvioletred', 'No': 'cornflowerblue'})
plt.show()

# %% [markdown]
# According to the figure above, attrition appears to be strongly correlated with employees' career history.
#
# ##### <span style="color:purple"> **Todo:** Represent attrition according to the worker's historical profile.</span>
#
# - Plot the total number of years worked as a function of (i) the number of years spent in this company, (ii) the number of years spent in the current position and, finally, (iii) the number of years since the last promotion.
# - Colour the dots according to attrition.

# %%
### TO BE COMPLETED ###

[...]

# %%
# %load solutions/history.py
cols = ['YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion']

fig,axes = plt.subplots(nrows=3, ncols=1, figsize=(10,10))

for i,c in enumerate(cols):
    sns.pointplot(x=data[c], y=data['TotalWorkingYears'], ax=axes[i], hue=data['Attrition'], palette={'Yes':'mediumvioletred', 'No':'cornflowerblue'})
    axes[i].set_xlabel(c)
    axes[i].set_ylabel('TotalWorkingYears')

plt.tight_layout()
plt.show()

# %% [markdown]
# > Comments.

# %% [markdown]
# ## Data Visualization¶

# %% [markdown]
# ### Breakdown of Overtime Work

# %% [markdown]
# ##### <span style="color:purple"> **Question:** What is the profile of employees working overtime?</span>
#
# View the distribution of overtime hours worked according to, for example, employees' marital status, department of practice, gender or age.
#
# You can use the [histplot](https://seaborn.pydata.org/generated/seaborn.histplot.html#seaborn.histplot) function.

# %%
### TO BE COMPLETED ###

[...]

# %%
# %load solutions/overtime.py
plt.figure(figsize=(10,8))

# --- #

plt.subplot(2,2,1)
sns.histplot(data, x="MaritalStatus", hue="OverTime", palette="rocket")
plt.title('Overtime by Marital Status')

# --- #

plt.subplot(2,2,2)
sns.histplot(data, x="Department", hue="OverTime", palette="rocket")
# plt.xticks(rotation=35)
plt.title('Overtime by Department')

# --- #

plt.subplot(2,2,3)
sns.histplot(data, x="Gender", hue="OverTime", palette="rocket")
plt.title('Overtime by Gender')

# --- #

plt.subplot(2,2,4)
sns.histplot(data, x='Age', hue='OverTime', palette="rocket", kde=True)
plt.title('Distribution of Age by OverTime')

plt.tight_layout()
plt.show()

# %% [markdown]
# > Comments.

# %% [markdown]
# ## Company Departure

# %% [markdown]
# ##### <span style="color:purple"> **Question:** What is the profile of employees working overtime?</span>
#
# Carry out the same exploratory study, but distinguish between employees who leave the company (attrition) and those who do not.

# %%
### TO BE COMPLETED ###

[...]

# %%
# %load solutions/attrition.py
plt.figure(figsize=(10,8))

# --- #

plt.subplot(2,2,1)
sns.histplot(data, x="MaritalStatus", hue="Attrition", palette={'Yes':'mediumvioletred', 'No':'cornflowerblue'})
plt.title('Attrition by Marital Status')

# --- #

plt.subplot(2,2,2)
sns.histplot(data, x="Department", hue="Attrition", palette={'Yes':'mediumvioletred', 'No':'cornflowerblue'})
# plt.xticks(rotation=35)
plt.title('Attrition by Department')

# --- #

plt.subplot(2,2,3)
sns.histplot(data, x="Gender", hue="Attrition", palette={'Yes':'mediumvioletred', 'No':'cornflowerblue'})
plt.title('Attrition by Gender')

# --- #

plt.subplot(2,2,4)
sns.histplot(data, x='Age', hue='Attrition', palette={'Yes':'mediumvioletred', 'No':'cornflowerblue'}, kde=True)
plt.title('Distribution of Age by Attrition')

plt.tight_layout()
plt.show()

# %% [markdown]
# > Comments.

# %% [markdown]
# ## One-hot Encoding of Categorical Data
#
# To facilitate statistical analysis (LDA decomposition), we will "translate" the various categorical variables into [one-hot](https://fr.wikipedia.org/wiki/Encodage_one-hot) encoder form.

# %% [markdown]
# ### Attrition

# %%
data.loc[data['Attrition']=='No','Attrition'] = 0
data.loc[data['Attrition']=='Yes','Attrition'] = 1

data['Attrition'] = data['Attrition'].astype('int')

# %% [markdown]
# ### Business Travel

# %%
BT = data['BusinessTravel'].unique()

for travel in BT:
    data['Business_'+travel] = 0
    data.loc[data['BusinessTravel']==travel,'Business_'+travel] = 1
    data['Business_'+travel] = data['Business_'+travel].astype('int')

data = data.drop('BusinessTravel',axis=1)
# data.head()

# %% [markdown]
# ### Working Department

# %%
DPT = data['Department'].unique()
DPT_names = ['Sales', 'R & D', 'Dpt HR']

for i, dpt in enumerate(DPT):
    data[DPT_names[i]] = 0
    data.loc[data['Department']==dpt, DPT_names[i]] = 1
    data[DPT_names[i]] = data[DPT_names[i]].astype('int')

data = data.drop('Department',axis=1)
# data.head()

# %% [markdown]
# ### Education Field

# %%
EDUC = data['EducationField'].unique()
EDUC_names = ['Life Sciences', 'Other', 'Medical', 'Marketing', 'Technical Degree', 'Educ HR']

for i, educ in enumerate(EDUC):
    data[EDUC_names[i]] = 0
    data.loc[data['EducationField']==educ, EDUC_names[i]] = 1
    data[EDUC_names[i]] = data[EDUC_names[i]].astype('int')

data = data.drop('EducationField',axis=1)
# data.head()

# %% [markdown]
# ### Gender

# %%
data.loc[data['Gender']=='Male','Gender'] = 1
data.loc[data['Gender']=='Female','Gender'] = 0

data['Gender'] = data['Gender'].astype('int')

# %% [markdown]
# ### Job Role

# %%
JOB = data['JobRole'].unique()
JOB_names = JOB
JOB_names[-1] = 'Job HR'

for i, job in enumerate(JOB):
    data[JOB_names[i]] = 0
    data.loc[data['JobRole']==job, JOB_names[i]] = 1
    data[JOB_names[i]] = data[JOB_names[i]].astype('int')

data = data.drop('JobRole',axis=1)
# data.head()

# %% [markdown]
# ### MaritalStatus

# %%
STATUS = data['MaritalStatus'].unique()
STATUS_names = STATUS

for i, statues in enumerate(STATUS):
    data[STATUS_names[i]] = 0
    data.loc[data['MaritalStatus']==statues, STATUS_names[i]] = 1
    data[STATUS_names[i]] = data[STATUS_names[i]].astype('int')

data = data.drop('MaritalStatus',axis=1)
# data.head()

# %% [markdown]
# ### OverTime

# %%
data.loc[data['OverTime']=='No','OverTime'] = 0
data.loc[data['OverTime']=='Yes','OverTime'] = 1

data['OverTime'] = data['OverTime'].astype('int')

# %% [markdown]
# We check:

# %%
data.dtypes
# Out:
# Age                           int64
# Attrition                     int64
# DailyRate                     int64
# DistanceFromHome              int64
# Education                     int64
# EnvironmentSatisfaction       int64
# Gender                        int64
# HourlyRate                    int64
# JobInvolvement                int64
# JobLevel                      int64
# JobSatisfaction               int64
# MonthlyIncome                 int64
# MonthlyRate                   int64
# NumCompaniesWorked            int64
# OverTime                      int64
# PercentSalaryHike             int64
# PerformanceRating             int64
# RelationshipSatisfaction      int64
# StockOptionLevel              int64
# TotalWorkingYears             int64
# TrainingTimesLastYear         int64
# WorkLifeBalance               int64
# YearsAtCompany                int64
# YearsInCurrentRole            int64
# YearsSinceLastPromotion       int64
# YearsWithCurrManager          int64
# Business_Travel_Rarely        int64
# Business_Travel_Frequently    int64
# Business_Non-Travel           int64
# Sales                         int64
# R & D                         int64
# Dpt HR                        int64
# Life Sciences                 int64
# Other                         int64
# Medical                       int64
# Marketing                     int64
# Technical Degree              int64
# Educ HR                       int64
# Sales Executive               int64
# Research Scientist            int64
# Laboratory Technician         int64
# Manufacturing Director        int64
# Healthcare Representative     int64
# Manager                       int64
# Sales Representative          int64
# Research Director             int64
# Job HR                        int64
# Single                        int64
# Married                       int64
# Divorced                      int64
# dtype: object

# %% [markdown]
# ## Prediction of Attrition by **Logistic Regression**

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report

from sklearn.linear_model import LogisticRegression

# %% [markdown]
# ##### <span style="color:purple"> **Todo:** Using the [`train_test_split`](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html) function, define a training and test data set.</span>

# %%
### TO BE COMPLETED ###

[...]

train_x, test_x, train_y, test_y = ...

# %%
# %load solutions/train_test_split.py
X = data.drop(['Attrition'],axis=1)
Y = data['Attrition']

train_x, test_x, train_y, test_y = train_test_split(X, Y, test_size=0.3, random_state=20)

# %% [markdown]
# ##### <span style="color:purple"> **Todo:** Implement attrition prediction using a logistic regression model.</span>

# %%
### TO BE COMPLETED ###

clf = LogisticRegression(solver='newton-cholesky')
clf.fit(...)

[...]

accuracy = ...

print( classification_report( ... ) )

# %%
# %load solutions/logistic_regression.py
clf = LogisticRegression(solver='newton-cholesky')
clf.fit(train_x, train_y)

# --- #

pred_y = clf.predict(test_x)

accuracy = accuracy_score(test_y, pred_y, normalize=True, sample_weight=None)
print('Accuray:',round(100*accuracy,2), '%')
print(' ')

# --- #

print(classification_report(test_y, pred_y))
# Out:
# Accuray: 88.89 %
#
#               precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94       371
#            1       0.73      0.47      0.57        70
#
#     accuracy                           0.89       441
#    macro avg       0.82      0.72      0.76       441
# weighted avg       0.88      0.89      0.88       441

# %% [markdown]
# > Comments

# %% [markdown]
# ## Prediction of Attrition by **Linear Discriminant Analysis** (LDA)

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# %% [markdown]
# ##### <span style="color:purple"> **Todo:** Implement attrition prediction using LDA decomposition.</span>

# %%
### TO BE COMPLETED ###

[...]

# %%
# %load solutions/linear_discriminant_analysis.py

# %% [markdown]
# > Comments.

# %% [markdown]
# ## Prediction of Attrition by **Quadratic Discriminant Analysis** (QDA)

# %%
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

# %% [markdown]
# ##### <span style="color:purple"> **Todo:** Implement attrition prediction using QDA decomposition.</span>

# %%
### TO BE COMPLETED ###

[...]

# %%
# %load solutions/quadratic_discriminant_analysis.py

# %% [markdown]
# > Comments.
